# %%
from statistics import mean
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from collections import deque
import os
import csv
import numpy as np
import random
import gym
from collections import deque
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

SCORES_CSV_PATH = "scores.csv"
SCORES_PNG_PATH = "scores.png"
SOLVED_CSV_PATH = "solved.csv"
SOLVED_PNG_PATH = "solved.png"
AVERAGE_SCORE_TO_SOLVE = 195
CONSECUTIVE_RUNS_TO_SOLVE = 100


class ScoreLogger:

    def __init__(self, env_name):
        self.scores = deque(maxlen=CONSECUTIVE_RUNS_TO_SOLVE)
        self.env_name = env_name

        if os.path.exists(SCORES_PNG_PATH):
            os.remove(SCORES_PNG_PATH)
        if os.path.exists(SCORES_CSV_PATH):
            os.remove(SCORES_CSV_PATH)

    def add_score(self, score, run):
        self._save_csv(SCORES_CSV_PATH, score)
        self._save_png(input_path=SCORES_CSV_PATH,
                       output_path=SCORES_PNG_PATH,
                       x_label="runs",
                       y_label="scores",
                       average_of_n_last=CONSECUTIVE_RUNS_TO_SOLVE,
                       show_goal=True,
                       show_trend=True,
                       show_legend=True)
        self.scores.append(score)
        mean_score = mean(self.scores)
        print("Scores: (min: " + str(min(self.scores)) + ", avg: " + str(mean_score) + ", max: " + str(max(self.scores)) + ")\n")
        if mean_score >= AVERAGE_SCORE_TO_SOLVE and len(self.scores) >= CONSECUTIVE_RUNS_TO_SOLVE:
            solve_score = run-CONSECUTIVE_RUNS_TO_SOLVE
            print("Solved in " + str(solve_score) + " runs, " + str(run) + " total runs.")
            self._save_csv(SOLVED_CSV_PATH, solve_score)
            self._save_png(input_path=SOLVED_CSV_PATH,
                           output_path=SOLVED_PNG_PATH,
                           x_label="trials",
                           y_label="steps before solve",
                           average_of_n_last=None,
                           show_goal=False,
                           show_trend=False,
                           show_legend=False)
            exit()

    def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
        x = []
        y = []
        with open(input_path, "r") as scores:
            reader = csv.reader(scores)
            data = list(reader)
            for i in range(0, len(data)):
                x.append(int(i))
                y.append(int(data[i][0]))

        plt.subplots()
        plt.plot(x, y, label="score per run")

        average_range = average_of_n_last if average_of_n_last is not None else len(x)
        plt.plot(x[-average_range:], [np.mean(y[-average_range:])] * len(y[-average_range:]), linestyle="--", label="last " + str(average_range) + " runs average")

        if show_goal:
            plt.plot(x, [AVERAGE_SCORE_TO_SOLVE] * len(x), linestyle=":", label=str(AVERAGE_SCORE_TO_SOLVE) + " score average goal")

        if show_trend and len(x) > 1:
            trend_x = x[1:]
            z = np.polyfit(np.array(trend_x), np.array(y[1:]), 1)
            p = np.poly1d(z)
            plt.plot(trend_x, p(trend_x), linestyle="-.",  label="trend")

        plt.title(self.env_name)
        plt.xlabel(x_label)
        plt.ylabel(y_label)

        if show_legend:
            plt.legend(loc="upper left")

        plt.savefig(output_path, bbox_inches="tight")
        plt.close()

    def _save_csv(self, path, score):
        if not os.path.exists(path):
            with open(path, "w"):
                pass
        scores_file = open(path, "a")
        with scores_file:
            writer = csv.writer(scores_file)
            writer.writerow([score])

ENV_NAME = "CartPole-v1"

GAMMA = 0.95
LEARNING_RATE = 0.001

MEMORY_SIZE = 1000000
BATCH_SIZE = 20

EXPLORATION_MAX = 1.0
EXPLORATION_MIN = 0.01
EXPLORATION_DECAY = 0.995


class DQNSolver:

    def __init__(self, observation_space, action_space):
        self.exploration_rate = EXPLORATION_MAX

        self.action_space = action_space
        self.memory = deque(maxlen=MEMORY_SIZE)

        self.model = Sequential()
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))
        self.model.add(Dense(24, activation="relu"))
        self.model.add(Dense(self.action_space, activation="linear"))
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() < self.exploration_rate:
            return random.randrange(self.action_space)
        q_values = self.model.predict(state)
        return np.argmax(q_values[0])

    def experience_replay(self):
        if len(self.memory) < BATCH_SIZE:
            return
        batch = random.sample(self.memory, BATCH_SIZE)
        for state, action, reward, state_next, terminal in batch:
            q_update = reward
            if not terminal:
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
            q_values = self.model.predict(state)
            q_values[0][action] = q_update
            self.model.fit(state, q_values, verbose=0)
        self.exploration_rate *= EXPLORATION_DECAY
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)


def cartpole():
    env = gym.make(ENV_NAME)
    score_logger = ScoreLogger(ENV_NAME)
    observation_space = env.observation_space.shape[0]
    action_space = env.action_space.n
    dqn_solver = DQNSolver(observation_space, action_space)
    run = 0
    while True:
        run += 1
        state = env.reset()
        state = np.reshape(state, [1, observation_space])
        step = 0
        while True:
            step += 1
            #env.render()
            action = dqn_solver.act(state)
            state_next, reward, terminal, info = env.step(action)
            reward = reward if not terminal else -reward
            state_next = np.reshape(state_next, [1, observation_space])
            dqn_solver.remember(state, action, reward, state_next, terminal)
            state = state_next
            if terminal:
                print("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
                score_logger.add_score(step, run)
                break
            dqn_solver.experience_replay()


if __name__ == "__main__":
    cartpole()
# Out:
# Run: 1, exploration: 0.9655206468094844, score: 27
# Scores: (min: 27, avg: 27, max: 27)
#
# Run: 2, exploration: 0.9000874278732445, score: 15
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:77: RankWarning: Polyfit may be poorly conditioned
# Scores: (min: 15, avg: 21, max: 27)
#
# Run: 3, exploration: 0.8183201210226743, score: 20
# Scores: (min: 15, avg: 20.666666666666668, max: 27)
#
# Run: 4, exploration: 0.7628626641409962, score: 15
# Scores: (min: 15, avg: 19.25, max: 27)
#
# Run: 5, exploration: 0.6027415843082742, score: 48
# Scores: (min: 15, avg: 25, max: 48)
#
# Run: 6, exploration: 0.5618938591163328, score: 15
# Scores: (min: 15, avg: 23.333333333333332, max: 48)
#
# Run: 7, exploration: 0.4883155414435353, score: 29
# Scores: (min: 15, avg: 24.142857142857142, max: 48)
#
# Run: 8, exploration: 0.4180382776616619, score: 32
# Scores: (min: 15, avg: 25.125, max: 48)
#
# Run: 9, exploration: 0.3420891339682016, score: 41
# Scores: (min: 15, avg: 26.88888888888889, max: 48)
#
# Run: 10, exploration: 0.2884855236625661, score: 35
# Scores: (min: 15, avg: 27.7, max: 48)
#
# Run: 11, exploration: 0.25450776877280124, score: 26
# Scores: (min: 15, avg: 27.545454545454547, max: 48)
#
# Run: 12, exploration: 0.16873052768933355, score: 83
# Scores: (min: 15, avg: 32.166666666666664, max: 83)
#
# Run: 13, exploration: 0.12365869841532712, score: 63
# Scores: (min: 15, avg: 34.53846153846154, max: 83)
#
# Run: 14, exploration: 0.051178420962124486, score: 177
# Scores: (min: 15, avg: 44.714285714285715, max: 177)
#
# Run: 15, exploration: 0.01476423357148172, score: 249
# Scores: (min: 15, avg: 58.333333333333336, max: 249)
#
# Run: 16, exploration: 0.01, score: 147
# Scores: (min: 15, avg: 63.875, max: 249)
#
# Run: 17, exploration: 0.01, score: 249
# Scores: (min: 15, avg: 74.76470588235294, max: 249)
#
# Run: 18, exploration: 0.01, score: 246
# Scores: (min: 15, avg: 84.27777777777777, max: 249)
#
# Run: 19, exploration: 0.01, score: 203
# Scores: (min: 15, avg: 90.52631578947368, max: 249)
#
# Run: 20, exploration: 0.01, score: 335
# Scores: (min: 15, avg: 102.75, max: 335)
#
# Run: 21, exploration: 0.01, score: 200
# Scores: (min: 15, avg: 107.38095238095238, max: 335)
#
# Run: 22, exploration: 0.01, score: 249
# Scores: (min: 15, avg: 113.81818181818181, max: 335)
#
# Run: 23, exploration: 0.01, score: 202
# Scores: (min: 15, avg: 117.65217391304348, max: 335)
#
# Run: 24, exploration: 0.01, score: 235
# Scores: (min: 15, avg: 122.54166666666667, max: 335)
#
# Run: 25, exploration: 0.01, score: 172
# Scores: (min: 15, avg: 124.52, max: 335)
#
# Run: 26, exploration: 0.01, score: 201
# Scores: (min: 15, avg: 127.46153846153847, max: 335)
#
# Run: 27, exploration: 0.01, score: 162
# Scores: (min: 15, avg: 128.74074074074073, max: 335)
#
# Run: 28, exploration: 0.01, score: 180
# Scores: (min: 15, avg: 130.57142857142858, max: 335)
#
# Run: 29, exploration: 0.01, score: 150
# Scores: (min: 15, avg: 131.24137931034483, max: 335)
#
# Run: 30, exploration: 0.01, score: 241
# Scores: (min: 15, avg: 134.9, max: 335)
#
# Run: 31, exploration: 0.01, score: 192
# Scores: (min: 15, avg: 136.74193548387098, max: 335)
#
# Run: 32, exploration: 0.01, score: 422
# Scores: (min: 15, avg: 145.65625, max: 422)
#
# Run: 33, exploration: 0.01, score: 136
# Scores: (min: 15, avg: 145.36363636363637, max: 422)
#
# Run: 34, exploration: 0.01, score: 131
# Scores: (min: 15, avg: 144.94117647058823, max: 422)
#
# Run: 35, exploration: 0.01, score: 147
# Scores: (min: 15, avg: 145, max: 422)
#
# Run: 36, exploration: 0.01, score: 182
# Scores: (min: 15, avg: 146.02777777777777, max: 422)
#
# Run: 37, exploration: 0.01, score: 208
# Scores: (min: 15, avg: 147.7027027027027, max: 422)
#
# Run: 38, exploration: 0.01, score: 200
# Scores: (min: 15, avg: 149.07894736842104, max: 422)
#
# Run: 39, exploration: 0.01, score: 258
# Scores: (min: 15, avg: 151.87179487179486, max: 422)
#
# Run: 40, exploration: 0.01, score: 203
# Scores: (min: 15, avg: 153.15, max: 422)
#
# Run: 41, exploration: 0.01, score: 199
# Scores: (min: 15, avg: 154.26829268292684, max: 422)
#
# Run: 42, exploration: 0.01, score: 176
# Scores: (min: 15, avg: 154.78571428571428, max: 422)
#
# Run: 43, exploration: 0.01, score: 185
# Scores: (min: 15, avg: 155.48837209302326, max: 422)
#
# Run: 44, exploration: 0.01, score: 220
# Scores: (min: 15, avg: 156.95454545454547, max: 422)
#
# Run: 45, exploration: 0.01, score: 252
# Scores: (min: 15, avg: 159.06666666666666, max: 422)
#
# Run: 46, exploration: 0.01, score: 151
# Scores: (min: 15, avg: 158.8913043478261, max: 422)
#
# Run: 47, exploration: 0.01, score: 163
# Scores: (min: 15, avg: 158.9787234042553, max: 422)
#
# Run: 48, exploration: 0.01, score: 177
# Scores: (min: 15, avg: 159.35416666666666, max: 422)
#
# Run: 49, exploration: 0.01, score: 152
# Scores: (min: 15, avg: 159.20408163265307, max: 422)
#
# Run: 50, exploration: 0.01, score: 165
# Scores: (min: 15, avg: 159.32, max: 422)
#
# Run: 51, exploration: 0.01, score: 153
# Scores: (min: 15, avg: 159.19607843137254, max: 422)
#
# Run: 52, exploration: 0.01, score: 150
# Scores: (min: 15, avg: 159.01923076923077, max: 422)
#
# Run: 53, exploration: 0.01, score: 189
# Scores: (min: 15, avg: 159.58490566037736, max: 422)
#
# Run: 54, exploration: 0.01, score: 178
# Scores: (min: 15, avg: 159.92592592592592, max: 422)
#
# Run: 55, exploration: 0.01, score: 228
# Scores: (min: 15, avg: 161.16363636363636, max: 422)
#
# Run: 56, exploration: 0.01, score: 187
# Scores: (min: 15, avg: 161.625, max: 422)
#
# Run: 57, exploration: 0.01, score: 214
# Scores: (min: 15, avg: 162.5438596491228, max: 422)
#
# Run: 58, exploration: 0.01, score: 142
# Scores: (min: 15, avg: 162.18965517241378, max: 422)
#
# Run: 59, exploration: 0.01, score: 139
# Scores: (min: 15, avg: 161.79661016949152, max: 422)
#
# Run: 60, exploration: 0.01, score: 162
# Scores: (min: 15, avg: 161.8, max: 422)
#
# Run: 61, exploration: 0.01, score: 162
# Scores: (min: 15, avg: 161.80327868852459, max: 422)
#
# Run: 62, exploration: 0.01, score: 179
# Scores: (min: 15, avg: 162.08064516129033, max: 422)
#
# Run: 63, exploration: 0.01, score: 159
# Scores: (min: 15, avg: 162.03174603174602, max: 422)
#
# Run: 64, exploration: 0.01, score: 229
# Scores: (min: 15, avg: 163.078125, max: 422)
#
# Run: 65, exploration: 0.01, score: 172
# Scores: (min: 15, avg: 163.2153846153846, max: 422)
#
# Run: 66, exploration: 0.01, score: 142
# Scores: (min: 15, avg: 162.8939393939394, max: 422)
#
# Run: 67, exploration: 0.01, score: 181
# Scores: (min: 15, avg: 163.16417910447763, max: 422)
#
# Run: 68, exploration: 0.01, score: 145
# Scores: (min: 15, avg: 162.89705882352942, max: 422)
#
# Run: 69, exploration: 0.01, score: 205
# Scores: (min: 15, avg: 163.5072463768116, max: 422)
#
# Run: 70, exploration: 0.01, score: 240
# Scores: (min: 15, avg: 164.6, max: 422)
#
# Run: 71, exploration: 0.01, score: 214
# Scores: (min: 15, avg: 165.29577464788733, max: 422)
#
# Run: 72, exploration: 0.01, score: 178
# Scores: (min: 15, avg: 165.47222222222223, max: 422)
#
# Run: 73, exploration: 0.01, score: 166
# Scores: (min: 15, avg: 165.4794520547945, max: 422)
#
# Run: 74, exploration: 0.01, score: 175
# Scores: (min: 15, avg: 165.6081081081081, max: 422)
#
# Run: 75, exploration: 0.01, score: 206
# Scores: (min: 15, avg: 166.14666666666668, max: 422)
#
# Run: 76, exploration: 0.01, score: 165
# Scores: (min: 15, avg: 166.1315789473684, max: 422)
#
# Run: 77, exploration: 0.01, score: 173
# Scores: (min: 15, avg: 166.2207792207792, max: 422)
#
# Run: 78, exploration: 0.01, score: 138
# Scores: (min: 15, avg: 165.85897435897436, max: 422)
#
# Run: 79, exploration: 0.01, score: 162
# Scores: (min: 15, avg: 165.81012658227849, max: 422)
#
# Run: 80, exploration: 0.01, score: 204
# Scores: (min: 15, avg: 166.2875, max: 422)
#
# Run: 81, exploration: 0.01, score: 143
# Scores: (min: 15, avg: 166, max: 422)
#
# Run: 82, exploration: 0.01, score: 275
# Scores: (min: 15, avg: 167.32926829268294, max: 422)
#
# Run: 83, exploration: 0.01, score: 157
# Scores: (min: 15, avg: 167.20481927710844, max: 422)
#
# Run: 84, exploration: 0.01, score: 127
# Scores: (min: 15, avg: 166.72619047619048, max: 422)
#
# Run: 85, exploration: 0.01, score: 222
# Scores: (min: 15, avg: 167.3764705882353, max: 422)
#
# Run: 86, exploration: 0.01, score: 176
# Scores: (min: 15, avg: 167.47674418604652, max: 422)
#
# Run: 87, exploration: 0.01, score: 180
# Scores: (min: 15, avg: 167.6206896551724, max: 422)
#
# Run: 88, exploration: 0.01, score: 141
# Scores: (min: 15, avg: 167.3181818181818, max: 422)
#
# Run: 89, exploration: 0.01, score: 156
# Scores: (min: 15, avg: 167.19101123595505, max: 422)
#
# Run: 90, exploration: 0.01, score: 202
# Scores: (min: 15, avg: 167.57777777777778, max: 422)
#
# Run: 91, exploration: 0.01, score: 235
# Scores: (min: 15, avg: 168.3186813186813, max: 422)
#
# Run: 92, exploration: 0.01, score: 114
# Scores: (min: 15, avg: 167.72826086956522, max: 422)
#
# Run: 93, exploration: 0.01, score: 192
# Scores: (min: 15, avg: 167.98924731182797, max: 422)
#
# Run: 94, exploration: 0.01, score: 160
# Scores: (min: 15, avg: 167.90425531914894, max: 422)
#
# Run: 95, exploration: 0.01, score: 175
# Scores: (min: 15, avg: 167.97894736842105, max: 422)
#
# Run: 96, exploration: 0.01, score: 167
# Scores: (min: 15, avg: 167.96875, max: 422)
#
# Run: 97, exploration: 0.01, score: 188
# Scores: (min: 15, avg: 168.17525773195877, max: 422)
#
# Run: 98, exploration: 0.01, score: 159
# Scores: (min: 15, avg: 168.08163265306123, max: 422)
#
# Run: 99, exploration: 0.01, score: 117
# Scores: (min: 15, avg: 167.56565656565655, max: 422)
#
# Run: 100, exploration: 0.01, score: 264
# Scores: (min: 15, avg: 168.53, max: 422)
#
# Run: 101, exploration: 0.01, score: 191
# Scores: (min: 15, avg: 170.17, max: 422)
#
# Run: 102, exploration: 0.01, score: 189
# Scores: (min: 15, avg: 171.91, max: 422)
#
# Run: 103, exploration: 0.01, score: 170
# Scores: (min: 15, avg: 173.41, max: 422)
#
# Run: 104, exploration: 0.01, score: 209
# Scores: (min: 15, avg: 175.35, max: 422)
#
# Run: 105, exploration: 0.01, score: 216
# Scores: (min: 15, avg: 177.03, max: 422)
#
# Run: 106, exploration: 0.01, score: 146
# Scores: (min: 26, avg: 178.34, max: 422)
#
# Run: 107, exploration: 0.01, score: 222
# Scores: (min: 26, avg: 180.27, max: 422)
#
# Run: 108, exploration: 0.01, score: 109
# Scores: (min: 26, avg: 181.04, max: 422)
#
# Run: 109, exploration: 0.01, score: 129
# Scores: (min: 26, avg: 181.92, max: 422)
#
# Run: 110, exploration: 0.01, score: 167
# Scores: (min: 26, avg: 183.24, max: 422)
#
# Run: 111, exploration: 0.01, score: 171
# Scores: (min: 63, avg: 184.69, max: 422)
#
# Run: 112, exploration: 0.01, score: 218
# Scores: (min: 63, avg: 186.04, max: 422)
#
# Run: 113, exploration: 0.01, score: 173
# Scores: (min: 109, avg: 187.14, max: 422)
#
# Run: 114, exploration: 0.01, score: 67
# Scores: (min: 67, avg: 186.04, max: 422)
#
# Run: 115, exploration: 0.01, score: 150
# Scores: (min: 67, avg: 185.05, max: 422)
#
# Run: 116, exploration: 0.01, score: 56
# Scores: (min: 56, avg: 184.14, max: 422)
#
# Run: 117, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 181.76, max: 422)
#
# Run: 118, exploration: 0.01, score: 157
# Scores: (min: 11, avg: 180.87, max: 422)
#
# Run: 119, exploration: 0.01, score: 123
# Scores: (min: 11, avg: 180.07, max: 422)
#
# Run: 120, exploration: 0.01, score: 144
# Scores: (min: 11, avg: 178.16, max: 422)
#
# Run: 121, exploration: 0.01, score: 145
# Scores: (min: 11, avg: 177.61, max: 422)
